# %% [markdown]
# # <font color=red>Matplotlib</font>
# ## A practical Matplotlib tutorial for Data Science by Ehsan Mokhtari
# ## I used 'Python Data Science Handbook by Jake VanderPlas' as a reference for this tutorial

# %% [markdown]
# ### Matplotlib is a multiplatform data visualization library built on NumPy arrays. One of Matplotlib’s most important features is its ability to play well with many operating systems and graphics backends.</br> just use <font color=green>pip install matplotlib</font> or use <font color=green>pip install matplotlib --upgrade</font> for updating it</br>for knowing more about functions just use <font color=green>help()</font> for example 'help(plt.hist)'

# %%
# we will use some standard shorthands for Matplotlib imports:
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# We use the plt.style directive to choose appropriate aesthetic styles for our figures.
print(plt.style.available[:10])
plt.style.use('classic')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot']

# %%
# Plotting from a script
# If you are using Matplotlib from within a script, use this at end of the script : plt.show()

# Plotting from an IPython notebook:
# %matplotlib inline will lead to static images of your plot embedded in the notebook

# %% [markdown]
# ## <font color = red> Simple plot</font>

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('classic')

x = np.linspace(0, 10, 100)

plt.plot(x, np.sin(x))
'''#plt.xlabel("angle") #plt.ylabel("sine") #plt.title('sine wave')'''
# Out:
# '#plt.xlabel("angle") #plt.ylabel("sine") #plt.title(\'sine wave\')'

# %% [markdown]
# ## <font color = red> Subplots</font>

# %%
''' In Matplotlib, the figure (an instance of the class plt.Figure) can be thought of as a
    single container that contains all the objects representing axes, graphics, text, and
    labels. The axes (an instance of the class plt.Axes) is what we see above: a bounding
    box with ticks and labels, which will eventually contain the plot elements that make
    up our visualization '''
#fig = plt.figure() # fig = plt.figure(figsize=(1, 1))  #fig.set_size_inches([5, 3])
#ax = plt.axes()    # ax = fig.add_axes([0,0,1,1])
#or # fig, ax = plt.subplots() 


# While this stateful interface is fast and convenient for simple plots, it can to run into problems.
# For example, once the second panel is created, how can we go back and add something to the first?
# subplots: groups of smaller axes that can exist together within a single figure
a = plt.subplot(2, 1, 1) # (rows, cols, panel number) 
''',sharey=True, sharex=True x or y axis will be shared among all subplots'''
a.plot(x, np.sin(x))
b = plt.subplot(2, 1, 2)
b.plot(x, np.cos(x))
#################################################
# The object-oriented interface is available for these more complicated situations, and
# for when you want more control over your figure!
fig, ax = plt.subplots(2,2)
ax[0][0].plot(x, np.sin(x))
ax[0][1].grid(True)
ax[1][0].grid(color='b', ls = '-.', lw = 0.25)
ax[1][1].plot(x, np.cos(x))
################################################
fig = plt.figure()
ax1 = plt.axes()                       # ax1.plot ...
ax2 = plt.axes([0.65, 0.65, 0.2, 0.2]) # ax2.hist ...
# or we can modify this way :
# fig = plt.figure()
# ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])   # main axes
# ax2 = fig.add_axes([0.55, 0.55, 0.3, 0.3]) # inset axes

# %%
fig = plt.figure()
grid = plt.GridSpec(2, 3, wspace=0.4, hspace=0.3)

a = plt.subplot(grid[0, 0])
a.yaxis.set_major_locator(plt.NullLocator())
a.xaxis.set_major_formatter(plt.NullFormatter())

b = plt.subplot(grid[0, 1:])
b.spines['left'].set_color('red')
b.spines['right'].set_color(None)

c = plt.subplot(grid[1, :2])
''' #c.set_xticklabels(['zero','one','two','three']) #,rotation=90
    #c.set_yticklabels([-1,0,1])'''
c.set_xticks([1,2,3,4])
c.set_yticks([-1,0,1])

d = plt.subplot(grid[1, 2]);

# %% [markdown]
# ## <font color = red> Simple Line Plots </font>

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 100)

ax.plot(x, np.sin(x), label='sin(x)'); #or plt.plot  but fig.plot throws error
ax.plot(x, np.sin(x - 1), color='red', label='sin(x-1)')
'''color='#FFDD44', color=(1.0,0.2,0.3)'''
ax.plot(x, np.sin(x - 2), color='green', linestyle='--', label='sin(x-2)',markersize=15, linewidth=4,
        markerfacecolor='white', markeredgecolor='gray',markeredgewidth=2, marker="o")
'''linestyle= '-', '-.', ':', None'''
ax.set(xlim=(0, 10), ylim=(-2, 2), xlabel='x', ylabel='sin(x)', title='A Sine Curve')
ax.legend(frameon=False, loc='lower center', ncol=3) 
'''fancybox=True, framealpha=0.5, shadow=True, borderpad=1, labels=['a', 'b', 'c']'''
# fig.savefig('my_figure.png')  #jpg, ...
# Out:
# "fancybox=True, framealpha=0.5, shadow=True, borderpad=1, labels=['a', 'b', 'c']"

# %% [markdown]
# ## <font color=red>Simple Scatter Plots</font>

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 50)
# ax.plot(x, np.sin(x), marker ='o', color='black')
# ax.plot(x, np.sin(x-1), '-o', color='red',markersize=15, linewidth=4, markerfacecolor='white',
                       # markeredgecolor='gray',markeredgewidth=2); # mixing dits with the line 
ax.scatter(x, np.sin(x), marker='o', color='green', alpha=1)
'''marker = 'o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd' '''
# Out:
# "marker = 'o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd' "

# %% [markdown]
# ## <font color = red>Visualizing Errors</font>

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)

ax.errorbar(x, y, yerr=dy, fmt='o', color='black', ecolor='lightgray', elinewidth=3, capsize=0)
# In addition to these options, you can also specify horizontal errorbars : xerr=dx
##############################################################################
# for drawing a 2d errorbar around a line
# plt.plot(xfit, yfit, '-', color='gray')
# plt.fill_between(xfit, yfit - dyfit, yfit + dyfit, color='gray', alpha=0.2)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ## <font color = red>Histograms</font>

# %%
fig = plt.figure()
ax = plt.axes()
data = np.random.randn(100)

# bins is the number of intervals we want
# bins=[150, 160, 170, 180] adjusted bins intervals for the hist
ax.hist(data, bins=30, alpha=0.5, histtype='stepfilled', color='steelblue', edgecolor='black')
'''label="hist", histtype="step", yerr=data.std(), density=True >>> probs instead of counts
   orientation{'vertical', 'horizontal'}, default: 'vertical' '''

# data2 = np.random.randn(100)
# ax[1].hist2d(data, data2, cmap='Blues', bins=30)       #plt.colorbar()
# plt.hexbin(data, data2, cmap='Blues', gridsize=30)   # plt.colorbar(label='count in bin')
# Out:
# 'label="hist", histtype="step", yerr=data.std(), density=True >>> probs instead of counts\n   orientation{\'vertical\', \'horizontal\'}, default: \'vertical\' '

# %% [markdown]
# ## <font color = red>Text and Annotation</font>

# %%
fig, ax = plt.subplots(figsize=(5, 5),facecolor='lightgray')

ax.text(.5,.5,"hello", fontsize=18, ha='center') # style='italic', bbox = {'facecolor': 'red'}

# ax.text(1, 5, "Data", transform=ax.transData) based on the x (index) and y of given and ploetd data
ax.text(0.5, 0.1, ". Axes: (0.5, 0.1)", transform=ax.transAxes) #based on Coordinates af axes
ax.text(0.2, 0.2, ". Figure: (0.2, 0.2)", transform=fig.transFigure); #based on Coordinates of figure

ax.annotate('this is hello', xy=(.6, .6), xytext=(.7, .9), arrowprops=dict(facecolor='black', shrink=0.05))
# Out:
# Text(0.7, 0.9, 'this is hello')

# %% [markdown]
# ## <font color = red>Bar Plot</font>

# %%
fig = plt.figure()
ax = plt.axes()

langs = ['C', 'C++', 'Java', 'Python', 'PHP']
boys_stu = [19,28,30,19,17]
girls_stu = [23,17,35,29,12]

ax.bar(langs,boys_stu, width = 0.35, color='b')
ax.bar(langs,girls_stu, width = 0.35, color='r', bottom=boys_stu) #stacekd bar
# bottom = boys_stu + girls_stu is used for third ax.bar if we want

# ax.barh(xdata,ydata) horizontal bar
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ## <font color=red>Pie Chart</font>

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')

langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23,17,35,29,12]

ax.pie(students, labels = langs,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x18e25c344d0>,
# ...
#  [Text(0.8934077559145442, 0.6417340427869932, 'C'),
#   Text(-0.14850004338941242, 1.0899301524012182, 'C++'),
#   Text(-1.0995966158072983, 0.02978728764317382, 'Java'),
#   Text(0.1485000433894123, -1.0899301524012182, 'Python'),
#   Text(1.042418501058071, -0.3512316452881833, 'PHP')],
#  [Text(0.48731332140793315, 0.35003675061108713, '19.83%'),
#   Text(-0.08100002366695222, 0.5945073558552099, '14.66%'),
#   Text(-0.5997799722585262, 0.01624761144173117, '30.17%'),
#   Text(0.08100002366695215, -0.5945073558552099, '25.00%'),
#   Text(0.5685919096680387, -0.19158089742991813, '10.34%')])

# %% [markdown]
# ## <font color = red>Contour Plot</font>
# ### Contour plots (sometimes called Level Plots) are a way to show a three-dimensional surface on a two-dimensional plane. It graphs two predictor variables X Y on the y-axis and a response variable Z as contours. A contour plot is appropriate if you want to see how alue Z changes as a function of two inputs X and Y, such that Z = f(X,Y). A contour line or isoline of a function of two variables is a curve along which the function has a constant value.</br>The independent variables x and y are usually restricted to a regular grid called meshgrid. The numpy.meshgrid creates a rectangular grid out of an array of x values and an array of y values.</br>Matplotlib API contains contour() and contourf() functions that draw contour lines and filled contours

# %%
fig,ax=plt.subplots(1,1)

xlist = np.linspace(-3.0, 3.0, 100)
ylist = np.linspace(-3.0, 3.0, 100)
X, Y = np.meshgrid(xlist, ylist)
Z = np.sqrt(X**2 + Y**2)

cp = ax.contourf(X, Y, Z)
fig.colorbar(cp) # Add a colorbar to a plot

# %% [markdown]
# ## <font color = red>Box Plot</font>
# ### A box plot which is also known as a whisker plot displays a summary of a set of data containing the minimum, first quartile, median, third quartile, and maximum. In a box plot, we draw a box from the first quartile to the third quartile. A vertical line goes through the box at the median. The whiskers go from each quartile to the minimum or maximum.

# %%
fig,ax=plt.subplots(1,2)

data1 = np.random.randint(0,10, size=100)
data2 = np.random.randint(0,10, size=100)

ax[0].boxplot([data1,data2])
ax[1].violinplot([data1,data2])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x18e27f670d0>,
# ...
#  'cmaxes': <matplotlib.collections.LineCollection at 0x18e25bb9ad0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x18e27fc7350>,
#  'cbars': <matplotlib.collections.LineCollection at 0x18e27fc8950>}

# %% [markdown]
# ## <font color = red>Three-Dimensional Plotting</font>

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

zline = np.linspace(0, 15, 100)
xline = np.sin(zline)
yline = np.cos(zline)

#ax.plot3D(xline, yline, zline, 'green')
ax.scatter3D(xline, yline, zline, c=zline, cmap='Greens')
# ax.scatter(xline, yline, zline, c=zline)

# %% [markdown]
# # <font color = red>Seaborn</font>
# ### Pandas + Matplotlib = Seaborn
# ### Seaborn provides an API on top of Matplotlib that offers sane choices for plot style and color defaults, defines simple high-level functions for common statistical plot types, and integrates with the functionality provided by Pandas DataFrames.</br> simply use <font color=green>pip install seaborn</font> or <font color=green>pip install seaborn --upgrade</font> for updating it.</br>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set() # Setting seaborn as default style even if use only matplotlib

# %%
# all data sets available for learning
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df = sns.load_dataset('titanic')
print('shape is : ',df.shape)
df.head()
# Out:
# shape is :  (891, 15)
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.set_style("darkgrid") # "ticks", "dark", "whitegrid"
sns.set_palette("rocket") # "Blues","mako, "flare", "crest", "viridis"
#sns.set_context("notebook", font_scale=1.25)   # Larger context: "talk", paper,  poster

# %%
sns.scatterplot(data=df, x='fare', y='age', hue='survived', hue_order=[1,0],
                palette={1: "blue",0: "#FF0000"}, style="sex") 
''' legend = {“auto”, “brief”, “full”, False}
    markers = "+" or {"male": "o", "female": "x"} '''
# Out:
# ' legend = {“auto”, “brief”, “full”, False}\n    markers = "+" or {"male": "o", "female": "x"} '

# %%
#sns.countplot(data = df, x='survived')
sns.countplot(data = df, x='survived', hue='sex', palette={"male": "#0000FF","female": "pink"}) 
# palette is based on hue parameters, also can be a list palette=["#0000FF", "pink"]
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
#sns.relplot(data = df, x='fare', y='age')
sns.relplot(data = df, x='fare', y='age', kind="scatter", col='sex', row="alive",
            hue='pclass', palette=["b", "r","g"], style='survived')
'''alpha=0.4, kind={"scatter", "line"}, col_wrap=2, palette=["b", "r"] '''
# Out:
# C:\Users\Ehsan\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# 'alpha=0.4, kind={"scatter", "line"}, col_wrap=2, palette=["b", "r"] '

# %%
s = sns.catplot(data=df, x="age", y="class",hue='sex',hue_order=['male','female'],palette=["blue", "red"])
sns.catplot(data=df, x="age", y="class", kind="box")
sns.catplot(data=df, x="age", y="class", hue="sex", kind="boxen")
# Out:
# C:\Users\Ehsan\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\Ehsan\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\Ehsan\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=df, x="age", y="class", hue="sex",kind="violin", bw=.25, cut=0, split=True,)
sns.catplot(data=df, x="class", y="survived", col="sex", kind="bar", height=4, aspect=.6,)
'''  kind = {"swarm","box","violin","boxen","point","bar","count"}, default="strip" '''
#   s.fig.suptitle("Our Title")
#   s.set(xlabel="x=age", ylabel="y=class")
# Out:
# C:\Users\Ehsan\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\Ehsan\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# '  kind = {"swarm","box","violin","boxen","point","bar","count"}, default="strip" '

# %%
sns.displot(df['age'], kde=True) #kde=False, bins=5, color='g',
# sns.kdeplot(df['age'])
# sns.despine(left=True)  #removes left despine of the plot
# Out:
# C:\Users\Ehsan\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
